# %%
import os
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=RuntimeWarning)

print(os.listdir("/kaggle/input"))
print(os.listdir("/kaggle/input/football-players-stats-2024-2025"))

#df = pd.read_csv("/kaggle/input/football-players-stats-2024-2025/players_data-2024_2025.csv")
df = pd.read_csv("C:\\Users\\USER\\Desktop\\Run\\players_data-2024_2025.csv")

# %%
remove = [
    'Rk', 'Born', 'MP', 'Starts', 'Min', 'G+A', 'G+A-PK', 'xG+xAG', 'npxG+xAG', 'Rk_stats_shooting', 'Nation_stats_shooting', 'Pos_stats_shooting', 'Comp_stats_shooting',
    'Age_stats_shooting', 'Born_stats_shooting', '90s_stats_shooting', 'Gls_stats_shooting', 'PK_stats_shooting','PKatt_stats_shooting', 'xG_stats_shooting', '90s', 'OG'
    'npxG_stats_shooting','Rk_stats_passing', 'Nation_stats_passing', 'Pos_stats_passing', 'Comp_stats_passing', 'Age_stats_passing', 'Born_stats_passing'
    '90s_stats_passing', 'Ast_stats_passing', 'xAG_stats_passing', 'PrgP_stats_passing', 'Rk_stats_passing_types', 'Nation_stats_passing_types', 'Dead', 'CK',
    'Pos_stats_passing_types', 'Comp_stats_passing_types', 'Age_stats_passing_types', 'Born_stats_passing_types', '90s_stats_passing_types', 'Att_stats_passing_types', 
    'FK_stats_passing_types', 'Cmp_stats_passing_types','SCA', 'GCA', 'Tkl+Int', 'Rk_stats_gca', 'Nation_stats_gca','Pos_stats_gca', 'Comp_stats_gca', 'Age_stats_gca', 
    'Born_stats_gca', '90s_stats_gca', 'Rk_stats_defense', 'Nation_stats_defense','Pos_stats_defense', 'Comp_stats_defense', 'Age_stats_defense','Born_stats_defense',
    '90s_stats_defense', 'Blocks_stats_defense','Sh_stats_defense', 'Rk_stats_possession', 'Nation_stats_possession','Pos_stats_possession', 'Comp_stats_possession', 
    'Age_stats_possession','Born_stats_possession', '90s_stats_possession', 'Mn/MP', 'Min%','Mn/Start', 'Compl', 'Mn/Sub', 'unsub', 'PPM', 'onG', 'onGA', '+/-',
    '+/-90','On-Off','onxG','onxGA','xG+/-','xG+/-90','W','D','L','Def 3rd_stats_possession','Mid 3rd_stats_possession','Att 3rd_stats_possession','Live_stats_possession', 
    'Att_stats_possession','TotDist_stats_possession', 'PrgDist_stats_possession','PrgC_stats_possession', '1/3_stats_possession', 'PrgR_stats_possession',
    'Rk_stats_playing_time', 'Nation_stats_playing_time','Pos_stats_playing_time', 'Comp_stats_playing_time','Age_stats_playing_time', 'Born_stats_playing_time',
    'MP_stats_playing_time', 'Min_stats_playing_time', '90s_stats_playing_time','Starts_stats_playing_time', 'Rk_stats_misc', 'Nation_stats_misc','Pos_stats_misc',
    'Comp_stats_misc', 'Age_stats_misc','Born_stats_misc', '90s_stats_misc', 'CrdY_stats_misc','CrdR_stats_misc', 'Fld_stats_misc', 'Off_stats_misc', "Won%", 'Save%', 'CS%',
    'Crs_stats_misc', 'Int_stats_misc', 'TklW_stats_misc', 'Lost_stats_misc','Rk_stats_keeper', 'Nation_stats_keeper', 'Pos_stats_keeper','Comp_stats_keeper', 
    'Age_stats_keeper', 'Born_stats_keeper','MP_stats_keeper', 'Starts_stats_keeper', 'Min_stats_keeper','90s_stats_keeper', 'PKatt_stats_keeper', 'Rk_stats_keeper_adv',
    'Nation_stats_keeper_adv', 'Pos_stats_keeper_adv','Comp_stats_keeper_adv', 'Age_stats_keeper_adv','Born_stats_keeper_adv', '90s_stats_keeper_adv', 'GA_stats_keeper_adv',
    'PKA_stats_keeper_adv', 'FK_stats_keeper_adv', 'CK_stats_keeper_adv','OG_stats_keeper_adv', 'Cmp_stats_keeper_adv', 'Att_stats_keeper_adv','Cmp%_stats_keeper_adv'
]

columns_to_remove = [col for col in remove if col in df.columns]
df.drop(columns=columns_to_remove, inplace=True)

# %%
# Fixing missing or incorrect player info

#Olabade Aluko
df.at[100, 'Nation'] = 'eng ENG'
df.at[100, 'Age'] = 18.0 
#Hannes Behrens 
df.at[273, 'Age'] = 20.0
# Pape Daouda Diongue
df.at[663, 'Age'] = 19.0 
#Jake Evans
df.at[862, 'Nation'] = 'eng ENG'
df.at[862, 'Age'] = 17.0 
# Atakan Karazor
df.at[1320, 'Nation'] = 'tr TUR'
#Fer López
df.at[1518, 'Nation'] = 'es ESP'
df.at[1518, 'Age'] = 21.0 
#Mateus Mane
df.at[1603, 'Nation'] = 'eng ENG'
df.at[1603, 'Age'] = 18.0 
#Max Moerstedt
df.at[1769, 'Age'] = 19.0 
#Jeremy Monga
df.at[1778, 'Nation'] = 'eng ENG'
df.at[1778, 'Age'] = 16.0 
#Plamedi Nsingi 
df.at[1917, 'Nation'] = 'non NON'

# %%
print("Before:", len(df))
df = df.drop_duplicates(subset=["Player"], keep="first")
print("After:", len(df))
# Out:
# Before: 2854
# After: 2702

# %%
print(list(df.columns))
print(len(df.columns))
# Out:
# ['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'CrdY', 'CrdR', 'xG', 'npxG', 'xAG', 'PrgC', 'PrgP', 'PrgR', 'Sh', 'SoT', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'Dist', 'FK', 'npxG_stats_shooting', 'npxG/Sh', 'G-xG', 'np:G-xG', 'Born_stats_passing', '90s_stats_passing', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist', 'xA', 'A-xAG', 'KP', '1/3', 'PPA', 'CrsPA', 'Live', 'TB', 'Sw', 'Crs', 'TI', 'In', 'Out', 'Str', 'Off', 'Blocks', 'SCA90', 'PassLive', 'PassDead', 'TO', 'Sh_stats_gca', 'Fld', 'Def', 'GCA90', 'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Att_stats_defense', 'Tkl%', 'Lost', 'Pass', 'Int', 'Clr', 'Err', 'Touches', 'Def Pen', 'Att Pen', 'Succ', 'Succ%', 'Tkld', 'Tkld%', 'Carries', 'CPA', 'Mis', 'Dis', 'Rec', 'Subs', 'unSub', '2CrdY', 'Fls', 'PKwon', 'PKcon', 'OG', 'Recov', 'Won', 'GA', 'GA90', 'SoTA', 'Saves', 'CS', 'PKA', 'PKsv', 'PKm', 'PSxG', 'PSxG/SoT', 'PSxG+/-', '/90', 'Att (GK)', 'Thr', 'Launch%', 'AvgLen', 'Opp', 'Stp', '
# ...

# %%
# Goolkeeper DataFrame
goalkeeper_stats = ['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age','GA','GA90','SoTA','Saves','Stp','Stp%','CS','PKA','PKsv','PKm','PSxG','PSxG/SoT','PSxG+/-',
                    '/90','Att (GK)','Thr','Launch%','AvgLen','Recov','Opp']

goalkeeper_stats = [col for col in goalkeeper_stats if col in df.columns]
gk_df = df[df['Pos'] == 'GK'][goalkeeper_stats].copy()

# Outfield Players DataFrame
outfield_stats = x = [
    'Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age', 'Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'xG', 'npxG', 'xAG', 'G-xG', 'np:G-xG','Sh', 'SoT', 'Sh/90', 
    'SoT/90', 'FK', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist', 'xA', 'A-xAG', 'KP', '1/3', 'PPA', 'CrsPA','Live', 'TB', 'Sw',
    'Crs', 'In', 'Out', 'Str', 'PrgC', 'PrgP', 'PrgR', 'SCA90', 'PassLive', 'PassDead', 'TO', 'Sh_stats_gca', 'Fld', 'Def', 'GCA90', 'Tkl', 'TklW', 'Def 3rd', 
    'Mid 3rd', 'Att 3rd', 'Lost', 'Int', 'Blocks', 'Pass', 'Clr', 'Err', 'Touches', 'Def Pen', 'Att Pen', 'Succ', 'Tkld', 'Carries', 
    'CPA', 'Mis', 'Dis', 'Rec', 'Won', 'Fls', 'PKwon', 'PKcon', 'Recov']

outfield_stats = [col for col in outfield_stats if col in df.columns]
of_df = df[df['Pos'] != 'GK'][outfield_stats].copy()

# %% [markdown]
# <hr style="border:2px solid #009B77; width:90%; margin:0 auto;" />
# <h1 style="text-align:center; color:#009B77; font-size:40px; margin:5px 0;">Goalkeeper</h1>
# <hr style="border:2px solid #009B77; width:90%; margin:15px auto 0 auto;" />

# %% [markdown]
# <h2 style="text-align:center; color:#1F77B4; font-size:25px; margin:15px 0;">
#     1. PCA + Exact k-NN
# </h2>
# <hr style="border:1.5px dashed #1F77B4; width:60%; margin:5px auto 15px auto;" />

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns

numeric_cols = gk_df.select_dtypes(include=[np.number]).columns.tolist()
feature_cols = [col for col in numeric_cols if col.lower() != 'age']

print(f"Total numeric columns: {len(numeric_cols)}")
print(f"Features for PCA (excluding Age): {len(feature_cols)}")
print(f"Feature columns: {feature_cols}")

gk_df[feature_cols] = gk_df[feature_cols].fillna(gk_df[feature_cols].median())
# Out:
# Total numeric columns: 21
# Features for PCA (excluding Age): 20
# Feature columns: ['GA', 'GA90', 'SoTA', 'Saves', 'Stp', 'Stp%', 'CS', 'PKA', 'PKsv', 'PKm', 'PSxG', 'PSxG/SoT', 'PSxG+/-', '/90', 'Att (GK)', 'Thr', 'Launch%', 'AvgLen', 'Recov', 'Opp']

# %%
player_names = gk_df['Player'].values

scaler = StandardScaler()
scaled_features = scaler.fit_transform(gk_df[feature_cols])

pca_temp = PCA()
pca_temp.fit(scaled_features)
cumsum = np.cumsum(pca_temp.explained_variance_ratio_)
n_components = np.argmax(cumsum >= 0.95) + 1
print(f"Components needed for 95% variance: {n_components}")

pca = PCA(n_components=n_components)
pca_features = pca.fit_transform(scaled_features)

print(f"PCA fitted with {n_components} components")
print(f"Total variance explained: {pca.explained_variance_ratio_.sum():.4f}")
# Out:
# Components needed for 95% variance: 10
# PCA fitted with 10 components
# Total variance explained: 0.9638

# %%
from sklearn.neighbors import NearestNeighbors


knn = NearestNeighbors(n_neighbors=4, metric='cosine', algorithm='brute')
knn.fit(pca_features)

n_comp_viz = min(3, pca.n_components_)
fig, axes = plt.subplots(1, n_comp_viz, figsize=(15, 5))

for i in range(n_comp_viz):
    axes[i].hist(pca_features[:, i], bins=50, edgecolor='black', alpha=0.7, color='steelblue')
    axes[i].set_xlabel(f'PC{i+1} (Var: {pca.explained_variance_ratio_[i]:.3f})', fontsize=12)
    axes[i].set_ylabel('Frequency', fontsize=12)
    axes[i].set_title(f'Distribution of PC{i+1}', fontsize=14, fontweight='bold')
    axes[i].grid(alpha=0.3)

plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(12, 10))

ax1 = plt.subplot(2, 2, 1)
scatter = ax1.scatter(pca_features[:, 0], pca_features[:, 1], 
                    alpha=0.6, c=range(len(pca_features)), cmap='viridis', s=30)
ax1.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.3f})', fontsize=11)
ax1.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.3f})', fontsize=11)
ax1.set_title('PCA: PC1 vs PC2', fontsize=13, fontweight='bold')
ax1.grid(alpha=0.3)

ax2 = plt.subplot(2, 2, 2)
cumsum_plot = np.cumsum(pca.explained_variance_ratio_)
ax2.plot(range(1, len(cumsum_plot)+1), cumsum_plot, marker='o', linewidth=2, markersize=6, color='red')
ax2.axhline(y=0.95, color='green', linestyle='--', label='95% Variance', linewidth=2)
ax2.set_xlabel('Number of Components', fontsize=11)
ax2.set_ylabel('Cumulative Variance Explained', fontsize=11)
ax2.set_title('Cumulative Variance Explained', fontsize=13, fontweight='bold')
ax2.legend()
ax2.grid(alpha=0.3)


ax3 = plt.subplot(2, 2, 3)
ax3.scatter(pca_features[:, 0], pca_features[:, 2], 
           alpha=0.6, c=range(len(pca_features)), cmap='plasma', s=30)
ax3.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.3f})', fontsize=11)
ax3.set_ylabel(f'PC3 ({pca.explained_variance_ratio_[2]:.3f})', fontsize=11)
ax3.set_title('PCA: PC1 vs PC3', fontsize=13, fontweight='bold')
ax3.grid(alpha=0.3)

ax4 = plt.subplot(2, 2, 4)
loadings = pca.components_[:2, :].T
top_features = 10
feature_importance = np.abs(loadings).sum(axis=1)
top_indices = np.argsort(feature_importance)[-top_features:]

y_pos = np.arange(top_features)
ax4.barh(y_pos, feature_importance[top_indices], color='teal', alpha=0.7)
ax4.set_yticks(y_pos)
ax4.set_yticklabels([feature_cols[i][:20] for i in top_indices], fontsize=9)
ax4.set_xlabel('Total Absolute Loading', fontsize=11)
ax4.set_title(f'Top {top_features} Feature Contributions', fontsize=13, fontweight='bold')
ax4.grid(alpha=0.3, axis='x')

plt.tight_layout()
plt.show()

# %%
player_to_search = "Thibaut Courtois"

player_mask = player_names == player_to_search
if not player_mask.any():
    player_mask = np.char.lower(player_names.astype(str)) == player_to_search.lower()
    if not player_mask.any():
        print(f"Player '{player_to_search}' not found in dataset.")
        print(f"Sample player names: {player_names[:5]}")
    else:
        player_idx = np.where(player_mask)[0][0]
else:
    player_idx = np.where(player_mask)[0][0]

if player_mask.any():
    player_pca = pca_features[player_idx].reshape(1, -1)
    
    distances, indices = knn.kneighbors(player_pca, n_neighbors=4)
    
    distances = distances[0][1:4]
    indices = indices[0][1:4]
    
    results = []
    for idx, dist in zip(indices, distances):
        player_info = {
            'Name': player_names[idx],
            'Distance': dist,
        }
        
        for col in ['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age']:
            if col in gk_df.columns:
                player_info[col] = gk_df.iloc[idx][col]
                
        results.append(player_info)
    
    results_gk_df = pd.DataFrame(results)
    
    # Professional formatted output
    print("\n" + "━" * 90)
    print(f"\t\t\t\tPLAYER SIMILARITY ANALYSIS")
    print("━" * 90 + "\n")
    
    print(f"  Target Player: {player_to_search}")
    
    player_info_items = []
    for col in ['Nation', 'Pos', 'Squad', 'Comp', 'Age']:
        if col in gk_df.columns:
            value = gk_df.iloc[player_idx][col]
            player_info_items.append(f"{col}: {value}")
    
    if player_info_items:
        print(f"  {' │ '.join(player_info_items)}")
    
    print("\n" + ("━" * 90 + "\n"))
    print("\t\t\t  TOP 3 MOST SIMILAR PLAYERS\n")
    
    from tabulate import tabulate
    
    table_data = []
    for i, (idx, dist) in enumerate(zip(indices, distances), 1):
        row = [f"#{i}", player_names[idx]]
        
        if 'Nation' in gk_df.columns:
            row.append(gk_df.iloc[idx]['Nation'])
        if 'Age' in gk_df.columns:
            age = gk_df.iloc[idx]['Age']
            row.append(f"{int(age)}" if pd.notna(age) else "N/A")
        if 'Squad' in gk_df.columns:
            row.append(gk_df.iloc[idx]['Squad'])
        
        row.append(f"{dist:.3f}")
        table_data.append(row)
    
    headers = ["Rank", "Player", "Nation", "Age", "Club", "Similarity"]
    
    print(tabulate(table_data, headers=headers, tablefmt="rounded_grid", 
                   stralign="left", numalign="right"))


    print("\n\n\n\n")
    similar_indices = indices
    
    fig, ax = plt.subplots(figsize=(16, 10))
    fig.patch.set_facecolor('#0d1117')
    ax.set_facecolor('#0d1117')
    
    ax.scatter(pca_features[:, 0], pca_features[:, 1], 
              alpha=0.15, c='#6e7681', s=80, label='All Players', edgecolors='none')
    
    for idx in similar_indices:
        ax.plot([pca_features[player_idx, 0], pca_features[idx, 0]], 
               [pca_features[player_idx, 1], pca_features[idx, 1]], 
               color='#58a6ff', alpha=0.4, linewidth=3, zorder=1)
    
    ax.scatter(pca_features[similar_indices, 0], 
              pca_features[similar_indices, 1],
              alpha=0.9, c='#58a6ff', s=600, marker='o', 
              label='Similar Players', edgecolors='white', linewidth=2.5, zorder=3)
    
    ax.scatter(pca_features[player_idx, 0], 
              pca_features[player_idx, 1],
              alpha=1.0, c='#f85149', s=900, marker='*', 
              label=f'{player_to_search}', edgecolors='white', linewidth=3, zorder=4)
    
    ax.annotate(player_to_search, 
               (pca_features[player_idx, 0], pca_features[player_idx, 1]),
               xytext=(15, 15), textcoords='offset points', fontsize=11, fontweight='bold',
               color='#f85149',
               bbox=dict(boxstyle='round,pad=0.5', facecolor='#0d1117', alpha=0.8, 
                        edgecolor='#f85149', linewidth=1.5),
               arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.3', 
                              color='#f85149', lw=2))
    
    for i, idx in enumerate(similar_indices):
        # Calculate offset direction
        offset_x = (pca_features[idx, 0] - pca_features[player_idx, 0]) * 0.08
        offset_y = (pca_features[idx, 1] - pca_features[player_idx, 1]) * 0.08
        
        stagger_x = (i % 3 - 1) * 0.05
        stagger_y = (i % 2) * 0.05
        
        name = player_names[idx][:15] + '...' if len(player_names[idx]) > 15 else player_names[idx]
        
        ax.annotate(f"{name}\nDist: {distances[i]:.2f}", 
                   (pca_features[idx, 0], pca_features[idx, 1]),
                   xytext=(10 + offset_x + stagger_x, 10 + offset_y + stagger_y), 
                   textcoords='offset points', fontsize=9, fontweight='bold',
                   color='#58a6ff',
                   bbox=dict(boxstyle='round,pad=0.4', facecolor='#0d1117', alpha=0.7, 
                            edgecolor='#58a6ff', linewidth=1),
                   arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.2', 
                                  color='#58a6ff', lw=1.5))
    
    ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})', 
                 fontsize=12, fontweight='bold', color='#c9d1d9', labelpad=10)
    ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})', 
                 fontsize=12, fontweight='bold', color='#c9d1d9', labelpad=10)
    ax.set_title(f'Player Similarity Map: {player_to_search}', 
                fontsize=16, fontweight='bold', color='#c9d1d9', pad=20)
    
    legend = ax.legend(loc='upper right', fontsize=10, framealpha=0.8, 
                      facecolor='#0d1117', edgecolor='#30363d', labelcolor='#c9d1d9', 
                      frameon=True)
    legend.get_frame().set_linewidth(1.5)
    
    ax.grid(True, alpha=0.7, color='#30363d', linestyle='--', linewidth=0.5)
    
    ax.tick_params(colors='#8b949e', labelsize=10)
    
    for spine in ax.spines.values():
        spine.set_edgecolor('#30363d')
        spine.set_linewidth(1.5)
    
    x_range = pca_features[:, 0].max() - pca_features[:, 0].min()
    y_range = pca_features[:, 1].max() - pca_features[:, 1].min()
    
    ax.set_xlim([pca_features[:, 0].min() - x_range*0.1, 
                 pca_features[:, 0].max() + x_range*0.1])
    ax.set_ylim([pca_features[:, 1].min() - y_range*0.1, 
                 pca_features[:, 1].max() + y_range*0.1])
    
    plt.tight_layout()
    plt.savefig(f'similarity_space_{player_to_search.replace(" ", "_")}2D.png', 
                dpi=300, facecolor='#0d1117', bbox_inches='tight')
    plt.show()
# Out:
# Player 'Thibaut Courtois' not found in dataset.
# Sample player names: ['Max Aarons' 'Rodrigo Abajas' 'James Abankwah' 'Keyliane Abdallah'
#  'Yunis Abdelhamid']

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(18, 10))
ax = fig.add_subplot(111, projection='3d')

fig.patch.set_facecolor('#0d1117')
ax.set_facecolor('#0d1117')

ax.scatter(pca_features[:, 0], pca_features[:, 1], pca_features[:, 2],
          c='#6e7681', alpha=0.15, s=20, depthshade=True)

for idx in similar_indices:
    ax.plot([pca_features[player_idx, 0], pca_features[idx, 0]], 
           [pca_features[player_idx, 1], pca_features[idx, 1]],
           [pca_features[player_idx, 2], pca_features[idx, 2]],
           color='#58a6ff', alpha=0.4, linewidth=2)

ax.scatter(pca_features[similar_indices, 0], 
          pca_features[similar_indices, 1],
          pca_features[similar_indices, 2],
          c='#58a6ff', s=300, alpha=0.9, 
          edgecolors='white', linewidth=2, depthshade=True)

ax.scatter(pca_features[player_idx, 0], 
          pca_features[player_idx, 1],
          pca_features[player_idx, 2],
          c='#f85149', s=500, marker='*', alpha=1.0,
          edgecolors='white', linewidth=2.5, depthshade=True)

label_offsets = []
for i, idx in enumerate(similar_indices):
    offset_x = (pca_features[idx, 0] - pca_features[player_idx, 0]) * 0.15
    offset_y = (pca_features[idx, 1] - pca_features[player_idx, 1]) * 0.15
    offset_z = (pca_features[idx, 2] - pca_features[player_idx, 2]) * 0.15
    
    stagger = (i % 3 - 1) * 0.1  # Creates -0.1, 0, 0.1 pattern
    
    name = player_names[idx][:15] + '...' if len(player_names[idx]) > 15 else player_names[idx]
    ax.text(pca_features[idx, 0] + offset_x, 
           pca_features[idx, 1] + offset_y, 
           pca_features[idx, 2] + offset_z + stagger,
           f'{name}', fontsize=9, color='#58a6ff', weight='bold',
           bbox=dict(boxstyle='round,pad=0.3', facecolor='#0d1117', 
                    edgecolor='#58a6ff', alpha=0.7, linewidth=1))

ax.text(pca_features[player_idx, 0], 
       pca_features[player_idx, 1], 
       pca_features[player_idx, 2] + 0.2,
       f'{player_to_search}', fontsize=11, color='#f85149', weight='bold',
       bbox=dict(boxstyle='round,pad=0.4', facecolor='#0d1117', 
                edgecolor='#f85149', alpha=0.8, linewidth=1.5))

ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})', 
             color='#c9d1d9', fontsize=11, weight='bold', labelpad=12)
ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})', 
             color='#c9d1d9', fontsize=11, weight='bold', labelpad=12)
ax.set_zlabel(f'PC3 ({pca.explained_variance_ratio_[2]:.1%})', 
             color='#c9d1d9', fontsize=11, weight='bold', labelpad=12)

ax.set_title(f'Player Similarity Map: {player_to_search}', 
            fontsize=16, color='#c9d1d9', weight='bold', pad=20)

ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
ax.grid(color='#30363d', linestyle='--', linewidth=0.5, alpha=0.7)

ax.tick_params(colors='#8b949e', labelsize=9)
for spine in [ax.xaxis.pane, ax.yaxis.pane, ax.zaxis.pane]:
    spine.set_edgecolor('#30363d')

x_range = pca_features[:, 0].max() - pca_features[:, 0].min()
y_range = pca_features[:, 1].max() - pca_features[:, 1].min()
z_range = pca_features[:, 2].max() - pca_features[:, 2].min()

ax.set_xlim([pca_features[:, 0].min() - x_range*0.1, 
             pca_features[:, 0].max() + x_range*0.1])
ax.set_ylim([pca_features[:, 1].min() - y_range*0.1, 
             pca_features[:, 1].max() + y_range*0.1])
ax.set_zlim([pca_features[:, 2].min() - z_range*0.15, 
             pca_features[:, 2].max() + z_range*0.15])

ax.view_init(elev=25, azim=45)

plt.tight_layout()
plt.savefig(f'similarity_space_{player_to_search.replace(" ", "_")}3D.png', 
            dpi=300, facecolor='#0d1117', bbox_inches='tight')
plt.show()

# %% [markdown]
# <hr style="border:2px solid #9467BD; width:90%; margin:0 auto;" />
# <h1 style="text-align:center; color:#9467BD; font-size:40px; margin:5px 0;">Outfield Players</h1>
# <hr style="border:2px solid #9467BD; width:90%; margin:15px auto 0 auto;" />

# %% [markdown]
# <h2 style="text-align:center; color:#1F77B4; font-size:25px; margin:15px 0;">
#     1. PCA + Exact k-NN
# </h2>
# <hr style="border:1.5px dashed #1F77B4; width:60%; margin:5px auto 15px auto;" />

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
import matplotlib.pyplot as plt
import seaborn as sns

numeric_cols = of_df.select_dtypes(include=[np.number]).columns.tolist()
feature_cols = [col for col in numeric_cols if col.lower() != 'age']

print(f"Total numeric columns: {len(numeric_cols)}")
print(f"Features for PCA (excluding Age): {len(feature_cols)}")
print(f"Feature columns: {feature_cols}")

of_df[feature_cols] = of_df[feature_cols].fillna(of_df[feature_cols].median())
# Out:
# Total numeric columns: 71
# Features for PCA (excluding Age): 70
# Feature columns: ['Gls', 'Ast', 'G-PK', 'PK', 'PKatt', 'xG', 'npxG', 'xAG', 'G-xG', 'np:G-xG', 'Sh', 'SoT', 'Sh/90', 'SoT/90', 'FK', 'Cmp', 'Att', 'Cmp%', 'TotDist', 'PrgDist', 'xA', 'A-xAG', 'KP', '1/3', 'PPA', 'CrsPA', 'Live', 'TB', 'Sw', 'Crs', 'In', 'Out', 'Str', 'PrgC', 'PrgP', 'PrgR', 'SCA90', 'PassLive', 'PassDead', 'TO', 'Sh_stats_gca', 'Fld', 'Def', 'GCA90', 'Tkl', 'TklW', 'Def 3rd', 'Mid 3rd', 'Att 3rd', 'Lost', 'Int', 'Blocks', 'Pass', 'Clr', 'Err', 'Touches', 'Def Pen', 'Att Pen', 'Succ', 'Tkld', 'Carries', 'CPA', 'Mis', 'Dis', 'Rec', 'Won', 'Fls', 'PKwon', 'PKcon', 'Recov']

# %%
player_names = of_df['Player'].values

scaler = StandardScaler()
scaled_features = scaler.fit_transform(of_df[feature_cols])

pca_temp = PCA()
pca_temp.fit(scaled_features)
cumsum = np.cumsum(pca_temp.explained_variance_ratio_)
n_components = np.argmax(cumsum >= 0.95) + 1
print(f"Components needed for 95% variance: {n_components}")

pca = PCA(n_components=n_components)
pca_features = pca.fit_transform(scaled_features)

print(f"PCA fitted with {n_components} components")
print(f"Total variance explained: {pca.explained_variance_ratio_.sum():.4f}")
# Out:
# Components needed for 95% variance: 26
# PCA fitted with 26 components
# Total variance explained: 0.9529

# %%
from sklearn.neighbors import NearestNeighbors

knn = NearestNeighbors(n_neighbors=4, metric='cosine', algorithm='auto')
knn.fit(pca_features)

n_comp_viz = min(3, pca.n_components_)
fig, axes = plt.subplots(1, n_comp_viz, figsize=(15, 5))

for i in range(n_comp_viz):
    axes[i].hist(pca_features[:, i], bins=50, edgecolor='black', alpha=0.7, color='steelblue')
    axes[i].set_xlabel(f'PC{i+1} (Var: {pca.explained_variance_ratio_[i]:.3f})', fontsize=12)
    axes[i].set_ylabel('Frequency', fontsize=12)
    axes[i].set_title(f'Distribution of PC{i+1}', fontsize=14, fontweight='bold')
    axes[i].grid(alpha=0.3)

plt.tight_layout()
plt.show()

fig = plt.figure(figsize=(12, 10))

ax1 = plt.subplot(2, 2, 1)
scatter = ax1.scatter(pca_features[:, 0], pca_features[:, 1], 
                    alpha=0.6, c=range(len(pca_features)), cmap='viridis', s=30)
ax1.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.3f})', fontsize=11)
ax1.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.3f})', fontsize=11)
ax1.set_title('PCA: PC1 vs PC2', fontsize=13, fontweight='bold')
ax1.grid(alpha=0.3)

ax2 = plt.subplot(2, 2, 2)
cumsum_plot = np.cumsum(pca.explained_variance_ratio_)
ax2.plot(range(1, len(cumsum_plot)+1), cumsum_plot, marker='o', linewidth=2, markersize=6, color='red')
ax2.axhline(y=0.95, color='green', linestyle='--', label='95% Variance', linewidth=2)
ax2.set_xlabel('Number of Components', fontsize=11)
ax2.set_ylabel('Cumulative Variance Explained', fontsize=11)
ax2.set_title('Cumulative Variance Explained', fontsize=13, fontweight='bold')
ax2.legend()
ax2.grid(alpha=0.3)


ax3 = plt.subplot(2, 2, 3)
ax3.scatter(pca_features[:, 0], pca_features[:, 2], 
           alpha=0.6, c=range(len(pca_features)), cmap='plasma', s=30)
ax3.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.3f})', fontsize=11)
ax3.set_ylabel(f'PC3 ({pca.explained_variance_ratio_[2]:.3f})', fontsize=11)
ax3.set_title('PCA: PC1 vs PC3', fontsize=13, fontweight='bold')
ax3.grid(alpha=0.3)

ax4 = plt.subplot(2, 2, 4)
loadings = pca.components_[:2, :].T
top_features = 10
feature_importance = np.abs(loadings).sum(axis=1)
top_indices = np.argsort(feature_importance)[-top_features:]

y_pos = np.arange(top_features)
ax4.barh(y_pos, feature_importance[top_indices], color='teal', alpha=0.7)
ax4.set_yticks(y_pos)
ax4.set_yticklabels([feature_cols[i][:20] for i in top_indices], fontsize=9)
ax4.set_xlabel('Total Absolute Loading', fontsize=11)
ax4.set_title(f'Top {top_features} Feature Contributions', fontsize=13, fontweight='bold')
ax4.grid(alpha=0.3, axis='x')

plt.tight_layout()
plt.show()

# %%
player_to_search = "Vinicius Júnior"

player_mask = player_names == player_to_search
if not player_mask.any():
    player_mask = np.char.lower(player_names.astype(str)) == player_to_search.lower()
    if not player_mask.any():
        print(f"Player '{player_to_search}' not found in dataset.")
        print(f"Sample player names: {player_names[:5]}")
    else:
        player_idx = np.where(player_mask)[0][0]
else:
    player_idx = np.where(player_mask)[0][0]

if player_mask.any():
    player_pca = pca_features[player_idx].reshape(1, -1)
    
    distances, indices = knn.kneighbors(player_pca, n_neighbors=4)
    
    distances = distances[0][1:4]
    indices = indices[0][1:4]
    
    results = []
    for idx, dist in zip(indices, distances):
        player_info = {
            'Name': player_names[idx],
            'Distance': dist,
        }
        
        for col in ['Player', 'Nation', 'Pos', 'Squad', 'Comp', 'Age']:
            if col in of_df.columns:
                player_info[col] = of_df.iloc[idx][col]
                
        results.append(player_info)
    
    results_of_df = pd.DataFrame(results)
    
    # Professional formatted output
    print("\n" + "━" * 90)
    print(f"\t\t\t\tPLAYER SIMILARITY ANALYSIS")
    print("━" * 90 + "\n")
    
    print(f"  Target Player: {player_to_search}")
    
    player_info_items = []
    for col in ['Nation', 'Pos', 'Squad', 'Comp', 'Age']:
        if col in of_df.columns:
            value = of_df.iloc[player_idx][col]
            player_info_items.append(f"{col}: {value}")
    
    if player_info_items:
        print(f"  {' │ '.join(player_info_items)}")
    
    print("\n" + ("━" * 90 + "\n"))
    print("\t\t\t  TOP 3 MOST SIMILAR PLAYERS\n")
    
    from tabulate import tabulate
    
    table_data = []
    for i, (idx, dist) in enumerate(zip(indices, distances), 1):
        row = [f"#{i}", player_names[idx]]
        
        if 'Nation' in of_df.columns:
            row.append(of_df.iloc[idx]['Nation'])
        if 'Pos' in of_df.columns:  # ADD THIS
            row.append(of_df.iloc[idx]['Pos'])
        if 'Age' in of_df.columns:
            age = of_df.iloc[idx]['Age']
            row.append(f"{int(age)}" if pd.notna(age) else "N/A")
        if 'Squad' in of_df.columns:
            row.append(of_df.iloc[idx]['Squad'])
        
        row.append(f"{dist:.3f}")
        table_data.append(row)
    
    headers = ["Rank", "Player", "Nation", "Position", "Age", "Club", "Similarity"]
    
    print(tabulate(table_data, headers=headers, tablefmt="rounded_grid", 
                   stralign="left", numalign="right"))


    print("\n\n\n\n")
    similar_indices = indices
    
    fig, ax = plt.subplots(figsize=(16, 10))
    fig.patch.set_facecolor('#0d1117')
    ax.set_facecolor('#0d1117')
    
    ax.scatter(pca_features[:, 0], pca_features[:, 1], 
              alpha=0.15, c='#6e7681', s=80, label='All Players', edgecolors='none')
    
    for idx in similar_indices:
        ax.plot([pca_features[player_idx, 0], pca_features[idx, 0]], 
               [pca_features[player_idx, 1], pca_features[idx, 1]], 
               color='#58a6ff', alpha=0.4, linewidth=3, zorder=1)
    
    ax.scatter(pca_features[similar_indices, 0], 
              pca_features[similar_indices, 1],
              alpha=0.9, c='#58a6ff', s=600, marker='o', 
              label='Similar Players', edgecolors='white', linewidth=2.5, zorder=3)
    
    ax.scatter(pca_features[player_idx, 0], 
              pca_features[player_idx, 1],
              alpha=1.0, c='#f85149', s=900, marker='*', 
              label=f'{player_to_search}', edgecolors='white', linewidth=3, zorder=4)
    
    ax.annotate(player_to_search, 
               (pca_features[player_idx, 0], pca_features[player_idx, 1]),
               xytext=(15, 15), textcoords='offset points', fontsize=11, fontweight='bold',
               color='#f85149',
               bbox=dict(boxstyle='round,pad=0.5', facecolor='#0d1117', alpha=0.8, 
                        edgecolor='#f85149', linewidth=1.5),
               arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.3', 
                              color='#f85149', lw=2))
    
    for i, idx in enumerate(similar_indices):
        # Calculate offset direction
        offset_x = (pca_features[idx, 0] - pca_features[player_idx, 0]) * 0.08
        offset_y = (pca_features[idx, 1] - pca_features[player_idx, 1]) * 0.08
        
        stagger_x = (i % 3 - 1) * 0.05
        stagger_y = (i % 2) * 0.05
        
        name = player_names[idx][:15] + '...' if len(player_names[idx]) > 15 else player_names[idx]
        
        ax.annotate(f"{name}\nDist: {distances[i]:.2f}", 
                   (pca_features[idx, 0], pca_features[idx, 1]),
                   xytext=(10 + offset_x + stagger_x, 10 + offset_y + stagger_y), 
                   textcoords='offset points', fontsize=9, fontweight='bold',
                   color='#58a6ff',
                   bbox=dict(boxstyle='round,pad=0.4', facecolor='#0d1117', alpha=0.7, 
                            edgecolor='#58a6ff', linewidth=1),
                   arrowprops=dict(arrowstyle='->', connectionstyle='arc3,rad=0.2', 
                                  color='#58a6ff', lw=1.5))
    
    ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})', 
                 fontsize=12, fontweight='bold', color='#c9d1d9', labelpad=10)
    ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})', 
                 fontsize=12, fontweight='bold', color='#c9d1d9', labelpad=10)
    ax.set_title(f'Player Similarity Map: {player_to_search}', 
                fontsize=16, fontweight='bold', color='#c9d1d9', pad=20)
    
    legend = ax.legend(loc='upper right', fontsize=10, framealpha=0.8, 
                      facecolor='#0d1117', edgecolor='#30363d', labelcolor='#c9d1d9', 
                      frameon=True)
    legend.get_frame().set_linewidth(1.5)
    
    ax.grid(True, alpha=0.7, color='#30363d', linestyle='--', linewidth=0.5)
    
    ax.tick_params(colors='#8b949e', labelsize=10)
    
    for spine in ax.spines.values():
        spine.set_edgecolor('#30363d')
        spine.set_linewidth(1.5)
    
    x_range = pca_features[:, 0].max() - pca_features[:, 0].min()
    y_range = pca_features[:, 1].max() - pca_features[:, 1].min()
    
    ax.set_xlim([pca_features[:, 0].min() - x_range*0.1, 
                 pca_features[:, 0].max() + x_range*0.1])
    ax.set_ylim([pca_features[:, 1].min() - y_range*0.1, 
                 pca_features[:, 1].max() + y_range*0.1])
    
    plt.tight_layout()
    plt.savefig(f'similarity_space_{player_to_search.replace(" ", "_")}2D.png', 
                dpi=300, facecolor='#0d1117', bbox_inches='tight')
    plt.show()
# Out:
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# 				PLAYER SIMILARITY ANALYSIS
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
#   Target Player: Vinicius Júnior
#   Nation: br BRA │ Pos: FW │ Squad: Real Madrid │ Comp: es La Liga │ Age: 24.0
#
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#
# 			  TOP 3 MOST SIMILAR PLAYERS
#
# ╭────────┬──────────────┬──────────┬────────────┬───────┬───────────┬──────────────╮
# │ Rank   │ Player       │ Nation   │ Position   │   Age │ Club      │   Similarity │
# ├────────┼──────────────┼──────────┼────────────┼───────┼───────────┼──────────────┤
# │ #1     │ Lamine Yamal │ es ESP   │ FW         │    17 │ Barcelona │        0.063 │
# ├────────┼──────────────┼──────────┼────────────┼───────┼───────────┼──────────────┤
# │ #2     │ Rafael Leão  │ pt POR   │ FW         │    25 │ Milan     │        0.064 │
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(18, 10))
ax = fig.add_subplot(111, projection='3d')

fig.patch.set_facecolor('#0d1117')
ax.set_facecolor('#0d1117')

ax.scatter(pca_features[:, 0], pca_features[:, 1], pca_features[:, 2],
          c='#6e7681', alpha=0.15, s=20, depthshade=True)

for idx in similar_indices:
    ax.plot([pca_features[player_idx, 0], pca_features[idx, 0]], 
           [pca_features[player_idx, 1], pca_features[idx, 1]],
           [pca_features[player_idx, 2], pca_features[idx, 2]],
           color='#58a6ff', alpha=0.4, linewidth=2)

ax.scatter(pca_features[similar_indices, 0], 
          pca_features[similar_indices, 1],
          pca_features[similar_indices, 2],
          c='#58a6ff', s=300, alpha=0.9, 
          edgecolors='white', linewidth=2, depthshade=True)

ax.scatter(pca_features[player_idx, 0], 
          pca_features[player_idx, 1],
          pca_features[player_idx, 2],
          c='#f85149', s=500, marker='*', alpha=1.0,
          edgecolors='white', linewidth=2.5, depthshade=True)

label_offsets = []
for i, idx in enumerate(similar_indices):
    offset_x = (pca_features[idx, 0] - pca_features[player_idx, 0]) * 0.15
    offset_y = (pca_features[idx, 1] - pca_features[player_idx, 1]) * 0.15
    offset_z = (pca_features[idx, 2] - pca_features[player_idx, 2]) * 0.15
    
    stagger = (i % 3 - 1) * 0.1  # Creates -0.1, 0, 0.1 pattern
    
    name = player_names[idx][:15] + '...' if len(player_names[idx]) > 15 else player_names[idx]
    ax.text(pca_features[idx, 0] + offset_x, 
           pca_features[idx, 1] + offset_y, 
           pca_features[idx, 2] + offset_z + stagger,
           f'{name}', fontsize=9, color='#58a6ff', weight='bold',
           bbox=dict(boxstyle='round,pad=0.3', facecolor='#0d1117', 
                    edgecolor='#58a6ff', alpha=0.7, linewidth=1))

ax.text(pca_features[player_idx, 0], 
       pca_features[player_idx, 1], 
       pca_features[player_idx, 2] + 0.2,
       f'{player_to_search}', fontsize=11, color='#f85149', weight='bold',
       bbox=dict(boxstyle='round,pad=0.4', facecolor='#0d1117', 
                edgecolor='#f85149', alpha=0.8, linewidth=1.5))

ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]:.1%})', 
             color='#c9d1d9', fontsize=11, weight='bold', labelpad=12)
ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]:.1%})', 
             color='#c9d1d9', fontsize=11, weight='bold', labelpad=12)
ax.set_zlabel(f'PC3 ({pca.explained_variance_ratio_[2]:.1%})', 
             color='#c9d1d9', fontsize=11, weight='bold', labelpad=12)

ax.set_title(f'Player Similarity Map: {player_to_search}', 
            fontsize=16, color='#c9d1d9', weight='bold', pad=20)

ax.xaxis.pane.fill = False
ax.yaxis.pane.fill = False
ax.zaxis.pane.fill = False
ax.grid(color='#30363d', linestyle='--', linewidth=0.5, alpha=0.7)

ax.tick_params(colors='#8b949e', labelsize=9)
for spine in [ax.xaxis.pane, ax.yaxis.pane, ax.zaxis.pane]:
    spine.set_edgecolor('#30363d')

x_range = pca_features[:, 0].max() - pca_features[:, 0].min()
y_range = pca_features[:, 1].max() - pca_features[:, 1].min()
z_range = pca_features[:, 2].max() - pca_features[:, 2].min()

ax.set_xlim([pca_features[:, 0].min() - x_range*0.1, 
             pca_features[:, 0].max() + x_range*0.1])
ax.set_ylim([pca_features[:, 1].min() - y_range*0.1, 
             pca_features[:, 1].max() + y_range*0.1])
ax.set_zlim([pca_features[:, 2].min() - z_range*0.15, 
             pca_features[:, 2].max() + z_range*0.15])

ax.view_init(elev=25, azim=45)

plt.tight_layout()
plt.savefig(f'similarity_space_{player_to_search.replace(" ", "_")}3D.png', 
            dpi=300, facecolor='#0d1117', bbox_inches='tight')
plt.show()
